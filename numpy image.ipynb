# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("edited design.png")

# %%
arr =  np.array(pil)

# %%
arr.shape
# Out:
# (628, 1200, 4)

# %%
cut = arr[:10,:10]
plt.imshow(cut)

# %%
# We can extract RGB from images as arr.shape gives three parameters
#  Which represents, Width, height and number of color layers in png it shows 4 layers

color = arr[:,:,0]
plt.imshow(color)

# %%
color = arr[:,:,1]
plt.imshow(color)

# %%
color = arr[:,:,2]
plt.imshow(color)

# %%
# Cutting all the color

work = arr.copy()

# %%
# Cutting 2ncolors the color 
# work[:,:,[1,2]] = 0

# Cuttiing one color 
work[:,:,[2]] = 0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)
plt.imshow(gray, cmap="gray")
